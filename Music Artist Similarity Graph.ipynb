# %%
print("This project is about Music Similarity Graph and Similar Artist Voice Recognition")
# Out:
# This project is about Music Similarity Graph and Similar Artist Voice Recognition

# %%
#spotipy lyricsgenius pandas networkx librosa
#this is already installed and executed so no need to execute again

# %%
import spotipy #spotipy is a package
from spotipy.oauth2 import SpotifyClientCredentials

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

auth = SpotifyClientCredentials(
    client_id="2e2a36d13bb84b66a5a8814e1b24f6ab",
    client_secret="2428851e4ec146a58c682ceb9592abe7"
)

sp = spotipy.Spotify(auth_manager=auth)

artist = sp.search(q="The Weeknd", type="artist", limit=1)
top = sp.artist_top_tracks(artist["artists"]["items"][0]["id"], country="US")

print([t["name"] for t in top["tracks"][:10]])
# Out:
# ['One Of The Girls (with JENNIE, Lily Rose Depp)', 'Timeless (feat Playboi Carti)', 'Starboy', 'Blinding Lights', 'Die For You', 'The Hills', 'Save Your Tears (Remix) (with Ariana Grande) - Bonus Track', 'Save Your Tears', 'Call Out My Name', 'São Paulo (feat. Anitta)']

# %%
auth = SpotifyClientCredentials(
    client_id="2e2a36d13bb84b66a5a8814e1b24f6ab",
    client_secret="2428851e4ec146a58c682ceb9592abe7"
)

sp = spotipy.Spotify(#from class Spotify and package spotipy
auth_manager=auth)

# %%
artist = sp.search (q="Brent Faiyaz", type= 'artist', limit=1)
print(artist)
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=1&query=Brent%20Faiyaz&type=artist', 'limit': 1, 'next': 'https://api.spotify.com/v1/search?offset=1&limit=1&query=Brent%20Faiyaz&type=artist', 'offset': 0, 'previous': None, 'total': 803, 'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3tlXnStJ1fFhdScmQeLpuG'}, 'followers': {'href': None, 'total': 8086019}, 'genres': ['r&b'], 'href': 'https://api.spotify.com/v1/artists/3tlXnStJ1fFhdScmQeLpuG', 'id': '3tlXnStJ1fFhdScmQeLpuG', 'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb582fbf712f5b6a9bf65d9b84', 'height': 640, 'width': 640}, {'url': 'https://i.scdn.co/image/ab67616100005174582fbf712f5b6a9bf65d9b84', 'height': 320, 'width': 320}, {'url': 'https://i.scdn.co/image/ab6761610000f178582fbf712f5b6a9bf65d9b84', 'height': 160, 'width': 160}], 'name': 'Brent Faiyaz', 'popularity': 82, 'type': 'artist', 'uri': 'spotify:artist:3tlXnStJ1fFhdScmQeLpuG'}]}}
