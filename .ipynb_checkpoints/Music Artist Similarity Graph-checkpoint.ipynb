# %%
print("This project is about Music Similarity Graph and Similar Artist Voice Recognition")
# Out:
# This project is about Music Similarity Graph and Similar Artist Voice Recognition

# %%
#spotipy lyricsgenius pandas networkx librosa
#this is already installed and executed so no need to execute again

# %%
import spotipy #spotipy is a package
from spotipy.oauth2 import SpotifyClientCredentials

# %%
auth = SpotifyClientCredentials(
    client_id="2e2a36d13bb84b66a5a8814e1b24f6ab",
    client_secret="2428851e4ec146a58c682ceb9592abe7"
)

sp = spotipy.Spotify(auth_manager=auth)

artist = sp.search(q="The Weeknd", type="artist", limit=1)
top = sp.artist_top_tracks(artist["artists"]["items"][0]["id"], country="US")

print([t["name"] for t in top["tracks"][:10]])
# Out:
# ['One Of The Girls (with JENNIE, Lily Rose Depp)', 'Timeless (feat Playboi Carti)', 'Starboy', 'Blinding Lights', 'Die For You', 'Save Your Tears (Remix) (with Ariana Grande) - Bonus Track', 'The Hills', 'Save Your Tears', 'São Paulo (feat. Anitta)', 'Call Out My Name']

# %%
auth = SpotifyClientCredentials(
    client_id="2e2a36d13bb84b66a5a8814e1b24f6ab",
    client_secret="2428851e4ec146a58c682ceb9592abe7"
)

sp = spotipy.Spotify(#from class Spotify and package spotipy
auth_manager=auth)

# %%
import lyricsgenius
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id="2e2a36d13bb84b66a5a8814e1b24f6ab",
    client_secret="2428851e4ec146a58c682ceb9592abe7"
))
genius = lyricsgenius.Genius("hVLdMrQqMDRVpKLNpvs9dxUz2V5RJ9PHX1bKf1cNuhoOKgP1hYiKJhYHlisrAAQA",skip_non_songs=True, remove_section_headers=True)

result = sp.search(q='Brent Faiyaz', type="artist", limit=1)
artist_id = result["artists"]["items"][0]["id"]
print(artist_id)
#we get the artist key here

adele=sp.search(q='Adele',type='artist',limit=1) #adele now has the info json info of the artist

print(adele["artists"]["items"][0]['images'][0]['url']) #multilevel indexing hierarchical indexing with nests
# Out:
# 3tlXnStJ1fFhdScmQeLpuG
# https://i.scdn.co/image/ab6761610000e5eb68f6e5892075d7f22615bd17

# %%
all_artists = []

#we have a special case here because we can only take 50 artists name at a time
#so the offset number is replaced by a loop that works automatically 
#the result obtained only has 14 output 


for offset in range(0, 1000, 50):
    result = sp.search(q='r&b', type="artist", limit=50, offset=offset)
    all_artists.extend(result['artists']['items'])

rnb_filtered = [
    artist for artist in all_artists
    if any(g in artist['genres'] for g in rnb_variants)
]


rnb_sorted = sorted(rnb_filtered, key=lambda x: x['popularity'], reverse=True)


top_100_rnb = rnb_sorted[:1000]

for i, artist in enumerate(top_100_rnb, 1):
    print(i, artist['name'], artist['popularity'])
#this code misses some names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 12
#       9     result = sp.search(q='r&b', type="artist", limit=50, offset=offset)
#      10     all_artists.extend(result['artists']['items'])
# ---> 12 rnb_filtered = [
#      13     artist for artist in all_artists
#      14     if any(g in artist['genres'] for g in rnb_variants)
#      15 ]
#      18 rnb_sorted = sorted(rnb_filtered, key=lambda x: x['popularity'], reverse=True)
#      21 top_100_rnb = rnb_sorted[:1000]
#
# Cell In[7], line 14, in <listcomp>(.0)
#       9     result = sp.search(q='r&b', type="artist", limit=50, offset=offset)
#      10     all_artists.extend(result['artists']['items'])
#      12 rnb_filtered = [
#      13     artist for artist in all_artists
# ---> 14     if any(g in artist['genres'] for g in rnb_variants)
#      15 ]
#      18 rnb_sorted = sorted(rnb_filtered, key=lambda x: x['popularity'], reverse=True)
#      21 top_100_rnb = rnb_sorted[:1000]
#
# NameError: name 'rnb_variants' is not defined

# %%
import requests
from bs4 import BeautifulSoup


url = "https://www.musicmetricsvault.com/genres/rb/12"


headers = {'User-Agent': 'Mozilla/5.0 (Educational Project)'}
response = requests.get(url, headers=headers)


soup = BeautifulSoup(response.text, 'html.parser')


rows = soup.find_all('tr')

top_100_artists = []


for row in rows[1:]:
    columns = row.find_all('td')
    

    if len(columns) > 1:
       
        rank = columns[0].get_text(strip=True)
        name = columns[1].get_text(strip=True)
        
        top_100_artists.append(name)
        
        # Stop once we have 100
        if len(top_100_artists) >= 100:
            break


for i, artist in enumerate(top_100_artists, 1):
    print(f"{i}. {artist}")
# Out:
# 1. SZA
# 2. Chris Brown
# 3. Beyoncé
# 4. Michael Jackson
# 5. USHER
# 6. Ne-Yo
# 7. Alicia Keys
# 8. PARTYNEXTDOOR
# 9. T-Pain
# 10. Kehlani
# 11. Miguel
# 12. GIVĒON
# 13. Bryson Tiller
# 14. Tory Lanez
# 15. Brent Faiyaz
# 16. Summer Walker
# 17. Big Sean
# 18. Jeremih
# 19. Kelly Rowland
# 20. Destiny's Child
# 21. Mary J. Blige
# 22. 6LACK
# 23. Ciara
# 24. Jhené Aiko
# 25. Jorja Smith
# 26. Mario
# 27. Keyshia Cole
# 28. Cassie
# 29. Normani
# 30. Lloyd
# 31. Wale
# 32. H.E.R.
# 33. Trey Songz
# 34. Boyz II Men
# 35. Ella Mai
# 36. Eve
# 37. Sonder
# 38. Brandy
# 39. Jacquees
# 40. Ashanti
# 41. Robin Thicke
# 42. Ginuwine
# 43. Estelle
# 44. Toni Braxton
# 45. Aaliyah
# 46. Monica
# 47. Jamie Foxx
# 48. Lucky Daye
# 49. Justine Skye
# 50. Erykah Badu
# 51. R. Kelly
# 52. Mýa
# 53. Tamia
# 54. Aloe Blacc
# 55. Keri Hilson
# 56. Fantasia
# 57. DeJ Loaf
# 58. 112
# 59. Teyana Taylor
# 60. Omarion
# 61. Avenoir
# 62. SWV
# 63. Bow Wow
# 64. Sisqo
# 65. Joe
# 66. The-Dream
# 67. Bobby V.
# 68. Sevyn Streeter
# 69. Keith Sweat
# 70. Jazmine Sullivan
# 71. Brian McKnight
# 72. K-Ci & JoJo
# 73. Maxwell
# 74. Emeli Sandé
# 75. Mase
# 76. August Alsina
# 77. SAYGRACE
# 78. Jagged Edge
# 79. All-4-One
# 80. Faith Evans
# 81. DaniLeigh
# 82. Pretty Ricky
# 83. Sabrina Claudio
# 84. Kiana Ledé
# 85. Musiq Soulchild
# 86. Queen Naija
# 87. Amerie
# 88. SoMo
# 89. Babyface
# 90. Remy Ma
# 91. 702
# 92. Next
# 93. Jodeci
# 94. Jennifer Hudson
# 95. Anthony Hamilton
# 96. Tyrese
# 97. Dru Hill
# 98. Donell Jones
# 99. B2K
# 100. Mila J

# %%
print(top_100_artists)
# Out:
# ['SZA', 'Chris Brown', 'Beyoncé', 'Michael Jackson', 'USHER', 'Ne-Yo', 'Alicia Keys', 'PARTYNEXTDOOR', 'T-Pain', 'Kehlani', 'Miguel', 'GIVĒON', 'Bryson Tiller', 'Tory Lanez', 'Brent Faiyaz', 'Summer Walker', 'Big Sean', 'Jeremih', 'Kelly Rowland', "Destiny's Child", 'Mary J. Blige', '6LACK', 'Ciara', 'Jhené Aiko', 'Jorja Smith', 'Mario', 'Keyshia Cole', 'Cassie', 'Normani', 'Lloyd', 'Wale', 'H.E.R.', 'Trey Songz', 'Boyz II Men', 'Ella Mai', 'Eve', 'Sonder', 'Brandy', 'Jacquees', 'Ashanti', 'Robin Thicke', 'Ginuwine', 'Estelle', 'Toni Braxton', 'Aaliyah', 'Monica', 'Jamie Foxx', 'Lucky Daye', 'Justine Skye', 'Erykah Badu', 'R. Kelly', 'Mýa', 'Tamia', 'Aloe Blacc', 'Keri Hilson', 'Fantasia', 'DeJ Loaf', '112', 'Teyana Taylor', 'Omarion', 'Avenoir', 'SWV', 'Bow Wow', 'Sisqo', 'Joe', 'The-Dream', 'Bobby V.', 'Sevyn Streeter', 'Keith Sweat', 'Jazmine Sullivan', 'Brian McKnight', 'K-Ci & JoJo', 'Maxwell', 'Emeli Sandé', 'Mase', 'August Alsina', 'SAYGRACE', 'Jagged Edge', 'All-4-One', 'Faith Evans', 'DaniLeigh', 'Pretty Ricky', 'Sabrina Claudio', 'Kiana Ledé', 'Musiq Soulchild', 'Queen Naija', 'Amerie', 'SoMo', 'Babyface', 'Remy Ma', '702', 'Next', 'Jodeci', 'Jennifer Hudson', 'Anthony Hamilton', 'Tyrese', 'Dru Hill', 'Donell Jones', 'B2K', 'Mila J']

# %%
#now we have a list of top 100 artists
#next step is to get the metadata for each of the artists
for artist in top_100_artists:
    artist_value = sp.search(q=artist,type='artist',limit=1)
    #print(artist_value)

# %%
import time

for x in top_100_artists:
    results = sp.search(q=f"artist:{x}", type='track', limit=50)
    tracks = results['tracks']['items']

    
    tracks.sort(key=lambda x: x['popularity'], reverse=True)

    print(f"\n Top 10 Solo Tracks for {x}")

    solo_top_tracks = []
    for track in tracks:
       
        if len(track['artists']) == 1:
            
            if track['name'] not in solo_top_tracks:
                solo_top_tracks.append(track['name'])
               
        
        if len(solo_top_tracks) == 10:
            break

    
    if solo_top_tracks:
        for i, song in enumerate(solo_top_tracks, 1):
            print(f"{i}. {song}")
    else:
        print("No solo tracks found.")
    print(f"Song names = {solo_top_tracks}")
time.sleep(0.5)
# Out:
#  Top 10 Solo Tracks for SZA
# 1. Snooze
# 2. Nobody Gets Me
# 3. Kill Bill
# 4. Saturn
# 5. Good Days
# 6. Broken Clocks
# 7. BMF
# 8. Low
# 9. Normal Girl
# 10. The Weekend
# Song names = ['Snooze', 'Nobody Gets Me', 'Kill Bill', 'Saturn', 'Good Days', 'Broken Clocks', 'BMF', 'Low', 'Normal Girl', 'The Weekend']
#
#  Top 10 Solo Tracks for Chris Brown
# 1. Under The Influence
# 2. Forever
# 3. With You
# 4. Angel Numbers / Ten Toes
# 5. Residuals
# 6. Yo (Excuse Me Miss)
# 7. Say Goodbye
# 8. Wall To Wall
# 9. Take You Down
# 10. Gimme That
# Song names = ['Under The Influence', 'Forever', 'With You', 'Angel Numbers / Ten Toes', 'Residuals', 'Yo (Excuse Me Miss)', 'Say Goodbye', 'Wall To Wall', 'Take You Down', 'Gimme That']
#
#  Top 10 Solo Tracks for Beyoncé
# 1. All Night
# 2. Haunted
# 3. Halo
# 4. CUFF IT
# 5. Irreplaceable
# 6. TEXAS HOLD 'EM
# 7. If I Were a Boy
# 8. Love On Top
# 9. Partition
# 10. Run the World (Girls)
# Song names = ['All Night', 'Haunted', 'Halo', 'CUFF IT', 'Irreplaceable', "TEXAS HOLD 'EM", 'If I Were a Boy', 'Love On Top', 'Partition', 'Run the World (Girls)']
#
#  Top 10 Solo Tracks for Michael Jackson
# 1. Billie Jean
# 2. Chicago
# 3. Beat It
# 4. Rock with You - Single Version
# 5. Don't Stop 'Til You Get Enough
# 6. Remember the Time
# 7. They Don't Care About Us
# 8. The Way You Make Me Feel - 2012 Remaster
# 9. Smooth Criminal - 2012 Remaster
# 10. You Rock My World
# Song names = ['Billie Jean', 'Chicago', 'Beat It', 'Rock with You - Single Version', "Don't Stop 'Til You Get Enough", 'Remember the Time', "They Don't Care About Us", 'The Way You Make Me Feel - 2012 Remaster', 'Smooth Criminal - 2012 Remaster', 'You Rock My World']
#
#  Top 10 Solo Tracks for USHER
# 1. Hey Daddy (Daddy's Home)
# 2. Burn
# 3. U Remind Me
# 4. U Got It Bad
# 5. Confessions Part II
# 6. More - RedOne Jimmy Joker Remix
# 7. You Make Me Wanna...
# 8. Scream
# 9. Nice & Slow - Radio Version
# 10. Caught Up
# Song names = ["Hey Daddy (Daddy's Home)", 'Burn', 'U Remind Me', 'U Got It Bad', 'Confessions Part II', 'More - RedOne Jimmy Joker Remix', 'You Make Me Wanna...', 'Scream', 'Nice & Slow - Radio Version', 'Caught Up']
#
#  Top 10 Solo Tracks for Ne-Yo
# 1. So Sick
# 2. Miss Independent
# 3. Because Of You
# 4. Sexy Love
# 5. Mad
# 6. Closer
# 7. Let Me Love You (Until You Learn To Love Yourself)
# 8. One In A Million
# 9. Go On Girl
# 10. Do You
# Song names = ['So Sick', 'Miss Independent', 'Because Of You', 'Sexy Love', 'Mad', 'Closer', 'Let Me Love You (Until You Learn To Love Yourself)', 'One In A Million', 'Go On Girl', 'Do You']
#
#  Top 10 Solo Tracks for Alicia Keys
# 1. If I Ain't Got You
# 2. Fallin'
# 3. No One
# 4. Girl on Fire
# 5. Empire State of Mind (Part II) Broken Down
# 6. You Don't Know My Name
# 7. Un-thinkable (I'm Ready)
# 8. Try Sleeping with a Broken Heart
# 9. Underdog
# 10. A Woman's Worth
# Song names = ["If I Ain't Got You", "Fallin'", 'No One', 'Girl on Fire', 'Empire State of Mind (Part II) Broken Down', "You Don't Know My Name", "Un-thinkable (I'm Ready)", 'Try Sleeping with a Broken Heart', 'Underdog', "A Woman's Worth"]
#
#  Top 10 Solo Tracks for PARTYNEXTDOOR
# 1. M a k e I t T o T h e M o r n i n g
# 2. Break from Toronto
# 3. Dreamin
# 4. Belong to the City
# 5. TBH
# 6. Her Way
# 7. N o C h i l l
# 8. Wus Good / Curious
# 9. Sex on the Beach
# 10. Ballin'
# Song names = ['M a k e I t T o T h e M o r n i n g', 'Break from Toronto', 'Dreamin', 'Belong to the City', 'TBH', 'Her Way', 'N o C h i l l', 'Wus Good / Curious', 'Sex on the Beach', "Ballin'"]
#
#  Top 10 Solo Tracks for T-Pain
# 1. I'm Sprung
# 2. Best Love Song
# 3. Club Husband
# 4. Drankin' Patna
# Song names = ["I'm Sprung", 'Best Love Song', 'Club Husband', "Drankin' Patna"]
#
#  Top 10 Solo Tracks for Kehlani
# 1. Folded
# 2. Out The Window
# 3. After Hours
# 4. Toxic
# 5. Can I
# 6. everything
# 7. Gangsta - Harley Quinn & Joker Flashback Version
# 8. Feels
# 9. You Know Wassup
# 10. Open (Passionate)
# Song names = ['Folded', 'Out The Window', 'After Hours', 'Toxic', 'Can I', 'everything', 'Gangsta - Harley Quinn & Joker Flashback Version', 'Feels', 'You Know Wassup', 'Open (Passionate)']
#
#  Top 10 Solo Tracks for Miguel
# 1. Sure Thing
# 2. Girl With The Tattoo Enter.lewd
# 3. Ahora Te Puedes Marchar
# 4. La Incondicional
# 5. La Mentira
# 6. Santa Claus Llegó a La Ciudad
# 7. Hasta Que Me Olvides
# 8. Y Que Fue?
# 9. Culpable O No - Miénteme Como Siempre
# 10. La Media Vuelta
# Song names = ['Sure Thing', 'Girl With The Tattoo Enter.lewd', 'Ahora Te Puedes Marchar', 'La Incondicional', 'La Mentira', 'Santa Claus Llegó a La Ciudad', 'Hasta Que Me Olvides', 'Y Que Fue?', 'Culpable O No - Miénteme Como Siempre', 'La Media Vuelta']
#
#  Top 10 Solo Tracks for GIVĒON
# 1. Like I Want You
# 2. Heartbreak Anniversary
# 3. TWENTIES
# 4. Stuck On You
# 5. Lost Me
# 6. The Beach
# 7. RATHER BE
# 8. All To Me
# 9. KEEPER
# 10. Still Your Best
# Song names = ['Like I Want You', 'Heartbreak Anniversary', 'TWENTIES', 'Stuck On You', 'Lost Me', 'The Beach', 'RATHER BE', 'All To Me', 'KEEPER', 'Still Your Best']
#
#  Top 10 Solo Tracks for Bryson Tiller
# 1. Don't
# 2. Right My Wrongs
# 3. Exchange
# 4. Whatever She Wants
# 5. Sorrows
# 6. Let Em' Know
# 7. Next To You
# 8. Sorry Not Sorry
# 9. Let Me Explain
# 10. Keep Doing What You're Doing
# Song names = ["Don't", 'Right My Wrongs', 'Exchange', 'Whatever She Wants', 'Sorrows', "Let Em' Know", 'Next To You', 'Sorry Not Sorry', 'Let Me Explain', "Keep Doing What You're Doing"]
#
#  Top 10 Solo Tracks for Tory Lanez
# 1. The Color Violet
# 2. Say It
# 3. Wish I Never Met You - Prison Tapes
# 4. Lady Of Namek
# 5. Lavender Sunflower
# 6. LUV
# 7. Broke In A Minute
# 8. P. Family
# 9. Let Me - Bonus
# 10. R.I.D.E.
# Song names = ['The Color Violet', 'Say It', 'Wish I Never Met You - Prison Tapes', 'Lady Of Namek', 'Lavender Sunflower', 'LUV', 'Broke In A Minute', 'P. Family', 'Let Me - Bonus', 'R.I.D.E.']
#
#  Top 10 Solo Tracks for Brent Faiyaz
# 1. ALL MINE
# 2. Been Away
# 3. Best Time
# 4. Poison
# 5. Clouded
# 6. Trust
# 7. Rehab (Winter In Paris)
# 8. Forever Yours
# 9. ROLE MODEL
# 10. DEAD MAN WALKING
# Song names = ['ALL MINE', 'Been Away', 'Best Time', 'Poison', 'Clouded', 'Trust', 'Rehab (Winter In Paris)', 'Forever Yours', 'ROLE MODEL', 'DEAD MAN WALKING']
#
#  Top 10 Solo Tracks for Summer Walker
# 1. Finally Over It
# 2. Session 32
# 3. Karma
# 4. FMT
# 5. Heart Of A Woman
# 6. Girls Need Love
# 7. Deep
# 8. No
# 9. Take Me Out This Club
# 10. Don't Make Me Do It/Tempted
# Song names = ['Finally Over It', 'Session 32', 'Karma', 'FMT', 'Heart Of A Woman', 'Girls Need Love', 'Deep', 'No', 'Take Me Out This Club', "Don't Make Me Do It/Tempted"]
#
#  Top 10 Solo Tracks for Big Sean
# 1. Why Would I Stop?
# 2. Precision
# Song names = ['Why Would I Stop?', 'Precision']
#
#  Top 10 Solo Tracks for Jeremih
# 1. oui
# 2. Birthday Sex
# 3. Love Don't Change
# 4. Remember Me
# 5. Imma Star (Everywhere We Are)
# Song names = ['oui', 'Birthday Sex', "Love Don't Change", 'Remember Me', 'Imma Star (Everywhere We Are)']
#
#  Top 10 Solo Tracks for Kelly Rowland
# 1. Work - Freemasons Radio Edit
# 2. Love You More At Christmas Time
# 3. Kisses Down Low
# 4. Stole
# 5. COFFEE
# 6. Work - Freemasons Club Mix
# 7. Dirty Laundry
# 8. Crazy
# 9. Kelly
# Song names = ['Work - Freemasons Radio Edit', 'Love You More At Christmas Time', 'Kisses Down Low', 'Stole', 'COFFEE', 'Work - Freemasons Club Mix', 'Dirty Laundry', 'Crazy', 'Kelly']
#
#  Top 10 Solo Tracks for Destiny's Child
# 1. Say My Name
# 2. 8 Days of Christmas
# 3. Bills, Bills, Bills
# 4. Jumpin', Jumpin'
# 5. Survivor
# 6. Lose My Breath
# 7. Independent Women, Pt. 1
# 8. Cater 2 U
# 9. Brown Eyes
# 10. Bootylicious
# Song names = ['Say My Name', '8 Days of Christmas', 'Bills, Bills, Bills', "Jumpin', Jumpin'", 'Survivor', 'Lose My Breath', 'Independent Women, Pt. 1', 'Cater 2 U', 'Brown Eyes', 'Bootylicious']
#
#  Top 10 Solo Tracks for Mary J. Blige
# 1. Family Affair
# 2. Be Without You - Kendu Mix
# 3. Mary Jane (All Night Long)
# 4. Just Fine
# 5. Real Love
# 6. Family Affair - Radio Edit
# 7. Share My World
# 8. My Life
# 9. I'm Goin' Down
# 10. Everything
# Song names = ['Family Affair', 'Be Without You - Kendu Mix', 'Mary Jane (All Night Long)', 'Just Fine', 'Real Love', 'Family Affair - Radio Edit', 'Share My World', 'My Life', "I'm Goin' Down", 'Everything']
#
#  Top 10 Solo Tracks for 6LACK
# 1. PRBLMS
# 2. Inwood Hill Park
# 3. Switch
# 4. Long Nights
# 5. Free
# 6. Ex Calling
# 7. Nonchalant
# 8. Luving U
# 9. Let Her Go
# 10. Never Know
# Song names = ['PRBLMS', 'Inwood Hill Park', 'Switch', 'Long Nights', 'Free', 'Ex Calling', 'Nonchalant', 'Luving U', 'Let Her Go', 'Never Know']
#  Top 10 Solo Tracks for Ciara
# 1. Like a Boy
# 2. Level Up
# 3. Body Party
# 4. Promise
# 5. I Bet
# 6. And I
# 7. Paint It, Black
# 8. How Deep Is Your Love
# 9. Dance Like We're Making Love
# 10. Got Me Good
# Song names = ['Like a Boy', 'Level Up', 'Body Party', 'Promise', 'I Bet', 'And I', 'Paint It, Black', 'How Deep Is Your Love', "Dance Like We're Making Love", 'Got Me Good']
#
#  Top 10 Solo Tracks for Jhené Aiko
# 1. stranger
# 2. The Worst
# 3. While We're Young
# 4. my mine
# 5. living room flow - Bonus
# 6. 2 seconds - Bonus
# 7. Blue Dream
# 8. W.A.Y.S.
# 9. Spotless Mind
# 10. 3:16AM
# Song names = ['stranger', 'The Worst', "While We're Young", 'my mine', 'living room flow - Bonus', '2 seconds - Bonus', 'Blue Dream', 'W.A.Y.S.', 'Spotless Mind', '3:16AM']
#
#  Top 10 Solo Tracks for Jorja Smith
# 1. The One
# 2. Blue Lights
# 3. Little Things x Gypsy Woman - L BEATS MASHUP
# 4. The Way I Love You
# 5. With You
# 6. Teenage Fantasy
# 7. The Way I Love You - Acoustic
# 8. Don't Watch Me Cry
# 9. Little Things
# 10. Tomorrow
# Song names = ['The One', 'Blue Lights', 'Little Things x Gypsy Woman - L BEATS MASHUP', 'The Way I Love You', 'With You', 'Teenage Fantasy', 'The Way I Love You - Acoustic', "Don't Watch Me Cry", 'Little Things', 'Tomorrow']
#
#  Top 10 Solo Tracks for Mario
# 1. Let Me Love You
# 2. How Do I Breathe
# 3. Voy a Olvidarme de Mí
# 4. Semata Karenamu
# 5. I Don't Wanna Know
# 6. Just a Friend 2002 - Radio Edit
# 7. Who Knows
# 8. Die Very Rough
# 9. I Choose You
# 10. Brindo
# Song names = ['Let Me Love You', 'How Do I Breathe', 'Voy a Olvidarme de Mí', 'Semata Karenamu', "I Don't Wanna Know", 'Just a Friend 2002 - Radio Edit', 'Who Knows', 'Die Very Rough', 'I Choose You', 'Brindo']
#
#  Top 10 Solo Tracks for Keyshia Cole
# 1. Love
# 2. I Should Have Cheated
# 3. Take Me Away
# 4. I Changed My Mind
# 5. You've Changed
# 6. You Complete Me
# 7. (I Just Want It) To Be Over
# 8. This Is Us
# 9. Have Yourself A Merry Little Christmas
# 10. We Could Be
# Song names = ['Love', 'I Should Have Cheated', 'Take Me Away', 'I Changed My Mind', "You've Changed", 'You Complete Me', '(I Just Want It) To Be Over', 'This Is Us', 'Have Yourself A Merry Little Christmas', 'We Could Be']
#
#  Top 10 Solo Tracks for Cassie
# 1. Long Way 2 Go
# 2. Me & U
# 3. Kiss Me
# 4. Is It You
# 5. Good Luck, Babe!
# 6. MONET (cver)
# 7. About Time
# 8. Just One Nite
# 9. Somewhere Only We Know
# 10. Me & U - US Version
# Song names = ['Long Way 2 Go', 'Me & U', 'Kiss Me', 'Is It You', 'Good Luck, Babe!', 'MONET (cver)', 'About Time', 'Just One Nite', 'Somewhere Only We Know', 'Me & U - US Version']
#
#  Top 10 Solo Tracks for Normani
# 1. Motivation
# 2. All Yours
# 3. Fair
# 4. Candy Paint
# 5. Lights On
# 6. Insomnia
# 7. Still
# 8. Take My Time
# 9. Little Secrets
# 10. Distance
# Song names = ['Motivation', 'All Yours', 'Fair', 'Candy Paint', 'Lights On', 'Insomnia', 'Still', 'Take My Time', 'Little Secrets', 'Distance']
#
#  Top 10 Solo Tracks for Lloyd
# 1. Nevermind
# 2. Present
# 3. Lay It Down
# 4. Get It Shawty
# 5. Want U Back
# 6. Player's Prayer
# 7. Tru
# 8. Caramel
# 9. Overture
# 10. Bakit Kung Sino Pa
# Song names = ['Nevermind', 'Present', 'Lay It Down', 'Get It Shawty', 'Want U Back', "Player's Prayer", 'Tru', 'Caramel', 'Overture', 'Bakit Kung Sino Pa']
#
#  Top 10 Solo Tracks for Wale
# 1. I Got Better
# 2. Last Night
# 3. I'm The Problem
# 4. Whiskey Glasses
# 5. Thinkin’ Bout Me
# 6. Cover Me Up
# 7. 20 Cigarettes
# 8. Love Somebody
# 9. Just In Case
# 10. More Than My Hometown
# Song names = ['I Got Better', 'Last Night', "I'm The Problem", 'Whiskey Glasses', 'Thinkin’ Bout Me', 'Cover Me Up', '20 Cigarettes', 'Love Somebody', 'Just In Case', 'More Than My Hometown']
#
#  Top 10 Solo Tracks for H.E.R.
# 1. Sleigh Ride
# 2. Frosty The Snowman
# 3. Every Kind Of Way
# 4. Focus
# 5. Comfortable
# 6. Damage
# 7. Take You There
# 8. FREUNDE
# 9. DAS WICHTIGSTE
# Song names = ['Sleigh Ride', 'Frosty The Snowman', 'Every Kind Of Way', 'Focus', 'Comfortable', 'Damage', 'Take You There', 'FREUNDE', 'DAS WICHTIGSTE']
#
#  Top 10 Solo Tracks for Trey Songz
# 1. Slow Motion
# 2. Can't Help but Wait
# 3. Na Na
# 4. Love Faces
# 5. Can't Be Friends
# 6. All We Do
# 7. Neighbors Know My Name
# 8. I Need a Girl
# 9. About You
# 10. Already Taken
# Song names = ['Slow Motion', "Can't Help but Wait", 'Na Na', 'Love Faces', "Can't Be Friends", 'All We Do', 'Neighbors Know My Name', 'I Need a Girl', 'About You', 'Already Taken']
#
#  Top 10 Solo Tracks for Boyz II Men
# 1. On Bended Knee
# 2. End Of The Road
# 3. I'll Make Love To You
# 4. Motownphilly
# 5. Water Runs Dry
# 6. A Song For Mama
# 7. Doin' Just Fine
# 8. 4 Seasons Of Loneliness
# 9. Dreams
# 10. Silent Night - Remastered 2024
# Song names = ['On Bended Knee', 'End Of The Road', "I'll Make Love To You", 'Motownphilly', 'Water Runs Dry', 'A Song For Mama', "Doin' Just Fine", '4 Seasons Of Loneliness', 'Dreams', 'Silent Night - Remastered 2024']
#
#  Top 10 Solo Tracks for Ella Mai
# 1. Little Things
# 2. This Is
# 3. Tell Her
# 4. DFMU
# 5. One Of These
# 6. Till My Heartaches End
# 7. Not Another Love Song
# 8. Hearts On Deck
# 9. made it out of mexico - acoustic
# 10. A Thousand Times
# Song names = ['Little Things', 'This Is', 'Tell Her', 'DFMU', 'One Of These', 'Till My Heartaches End', 'Not Another Love Song', 'Hearts On Deck', 'made it out of mexico - acoustic', 'A Thousand Times']
#
#  Top 10 Solo Tracks for Eve
# 1. I See Red
# 2. What It's Like
# 3. Kaikai Kitan
# 4. Santa Monica
# 5. All I Have to Do Is Dream
# 6. Who's That Girl?
# 7. Snow on The Bluff
# 8. Inside Out
# 9. Father Of Mine
# 10. Underdog
# Song names = ['I See Red', "What It's Like", 'Kaikai Kitan', 'Santa Monica', 'All I Have to Do Is Dream', "Who's That Girl?", 'Snow on The Bluff', 'Inside Out', 'Father Of Mine', 'Underdog']
#
#  Top 10 Solo Tracks for Sonder
# 1. What You Heard
# 2. One Night Only
# 3. Too Fast
# 4. Care
# 5. Mad Riches
# 6. Searchin
# 7. Feel
# 8. Lovely
# 9. Break You Off
# 10. Indonesian Fantasies
# Song names = ['What You Heard', 'One Night Only', 'Too Fast', 'Care', 'Mad Riches', 'Searchin', 'Feel', 'Lovely', 'Break You Off', 'Indonesian Fantasies']
#
#  Top 10 Solo Tracks for Brandy
# 1. I Wanna Be Down
# 2. Have You Ever
# 3. Arizona B
# 4. Sittin' Up In My Room
# 5. Best Friend
# 6. Almost Doesn't Count
# 7. Full Moon
# 8. Afrodisiac
# 9. Right Here (Departed)
# 10. Baby
# Song names = ['I Wanna Be Down', 'Have You Ever', 'Arizona B', "Sittin' Up In My Room", 'Best Friend', "Almost Doesn't Count", 'Full Moon', 'Afrodisiac', 'Right Here (Departed)', 'Baby']
#
#  Top 10 Solo Tracks for Jacquees
# 1. B.E.D.
# 2. You
# 3. Who's
# 4. Come Thru
# 5. He Kant
# 6. Feel It (feat. Lloyd, Rich Homie Quan)
# 7. Woman's Worth
# 8. Middle Of The Night
# 9. Say Yea
# 10. 23
# Song names = ['B.E.D.', 'You', "Who's", 'Come Thru', 'He Kant', 'Feel It (feat. Lloyd, Rich Homie Quan)', "Woman's Worth", 'Middle Of The Night', 'Say Yea', '23']
#
#  Top 10 Solo Tracks for Ashanti
# 1. Foolish
# 2. Rock Wit U (Awww Baby)
# 3. Unfoolish
# 4. Happy
# 5. Rain On Me
# 6. Baby
# 7. Christmas Time Again
# 8. Joy To The World
# 9. Only U
# 10. 235 (2:35 I Want You)
# Song names = ['Foolish', 'Rock Wit U (Awww Baby)', 'Unfoolish', 'Happy', 'Rain On Me', 'Baby', 'Christmas Time Again', 'Joy To The World', 'Only U', '235 (2:35 I Want You)']
#
#  Top 10 Solo Tracks for Robin Thicke
# 1. Lost Without U
# 2. Magic
# 3. Morning Sun
# 4. The Sweetest Love
# 5. Perfect Holiday
# 6. When I Get You Alone
# 7. Take Me Higher
# 8. Look Easy
# 9. Sex Therapy
# 10. Get Her Back
# Song names = ['Lost Without U', 'Magic', 'Morning Sun', 'The Sweetest Love', 'Perfect Holiday', 'When I Get You Alone', 'Take Me Higher', 'Look Easy', 'Sex Therapy', 'Get Her Back']
#
#  Top 10 Solo Tracks for Ginuwine
# 1. Pony
# 2. So Anxious
# 3. Differences
# 4. None Of Ur Friends Business
# 5. In Those Jeans
# 6. None Of Ur Friends Business - Radio Edit
# 7. Stingy
# 8. Same Ol' G
# 9. Love You More
# 10. I'll Do Anything/I'm Sorry
# Song names = ['Pony', 'So Anxious', 'Differences', 'None Of Ur Friends Business', 'In Those Jeans', 'None Of Ur Friends Business - Radio Edit', 'Stingy', "Same Ol' G", 'Love You More', "I'll Do Anything/I'm Sorry"]
#
#  Top 10 Solo Tracks for Estelle
# 1. El Burrito Sabanero - Tuki-Tuki Version
# 2. Campana Sobre Campana - Extended Mix
# 3. Rodolfo el Reno - Extended Mix
# 4. Feliz Navidad - J. Feliciano vs Boney M
# 5. American Boy - No Rap Version
# 6. Come Over
# 7. Lights Out
# 8. Little Tokyo
# 9. Dreamer Lounge
# 10. ZONE
# Song names = ['El Burrito Sabanero - Tuki-Tuki Version', 'Campana Sobre Campana - Extended Mix', 'Rodolfo el Reno - Extended Mix', 'Feliz Navidad - J. Feliciano vs Boney M', 'American Boy - No Rap Version', 'Come Over', 'Lights Out', 'Little Tokyo', 'Dreamer Lounge', 'ZONE']
#  Top 10 Solo Tracks for Toni Braxton
# 1. Un-Break My Heart
# 2. He Wasn't Man Enough
# 3. You're Makin' Me High
# 4. Breathe Again
# 5. Spanish Guitar
# 6. Another Sad Love Song
# 7. Please
# 8. I Love Me Some Him
# 9. Just Be A Man About It
# 10. Holiday Celebrate
# Song names = ['Un-Break My Heart', "He Wasn't Man Enough", "You're Makin' Me High", 'Breathe Again', 'Spanish Guitar', 'Another Sad Love Song', 'Please', 'I Love Me Some Him', 'Just Be A Man About It', 'Holiday Celebrate']
#
#  Top 10 Solo Tracks for Aaliyah
# 1. Try Again
# 2. Are You That Somebody?
# 3. One In A Million
# 4. Rock The Boat
# 5. At Your Best (You Are Love)
# 6. Age Ain't Nothing But a Number
# 7. Back & Forth
# 8. Are You That Somebody
# 9. More Than A Woman
# 10. Miss You
# Song names = ['Try Again', 'Are You That Somebody?', 'One In A Million', 'Rock The Boat', 'At Your Best (You Are Love)', "Age Ain't Nothing But a Number", 'Back & Forth', 'Are You That Somebody', 'More Than A Woman', 'Miss You']
#
#  Top 10 Solo Tracks for Monica
# 1. Karena Ku Sanggup
# 2. Matahariku
# 3. Rindu
# 4. Rapuh
# 5. Malam Tak Berjudul
# 6. Solo Se Vive una Vez
# 7. So Gone
# 8. Angel of Mine
# 9. Oyeme
# 10. El Amor Coloca
# Song names = ['Karena Ku Sanggup', 'Matahariku', 'Rindu', 'Rapuh', 'Malam Tak Berjudul', 'Solo Se Vive una Vez', 'So Gone', 'Angel of Mine', 'Oyeme', 'El Amor Coloca']
#
#  Top 10 Solo Tracks for Jamie Foxx
# 1. Infatuation
# 2. Do What It Do
# 3. Can I Take U Home - Main
# 4. Slow
# 5. Storm (Forecass)
# 6. Overdose
# 7. I Don't Need It
# 8. Three Letter Word
# Song names = ['Infatuation', 'Do What It Do', 'Can I Take U Home - Main', 'Slow', 'Storm (Forecass)', 'Overdose', "I Don't Need It", 'Three Letter Word']
#
#  Top 10 Solo Tracks for Lucky Daye
# 1. Over
# 2. That's You
# 3. Roll Some Mo
# 4. Careful (From The Original Motion Picture "Magic Mike's Last Dance")
# 5. Late Night
# 6. HERicane
# 7. Guess
# 8. Love You Too Much
# 9. Over - Sped Up
# 10. Floods
# Song names = ['Over', "That's You", 'Roll Some Mo', 'Careful (From The Original Motion Picture "Magic Mike\'s Last Dance")', 'Late Night', 'HERicane', 'Guess', 'Love You Too Much', 'Over - Sped Up', 'Floods']
#
#  Top 10 Solo Tracks for Justine Skye
# 1. Collide (Solo Version)
# 2. YAP
# 3. Whip It Up
# 4. Bitch In Ibiza
# 5. Conscious
# 6. In My Bag
# 7. What A Lie
# 8. Mmm Mmm
# 9. MAYBE
# 10. When You're Ready
# Song names = ['Collide (Solo Version)', 'YAP', 'Whip It Up', 'Bitch In Ibiza', 'Conscious', 'In My Bag', 'What A Lie', 'Mmm Mmm', 'MAYBE', "When You're Ready"]
#
#  Top 10 Solo Tracks for Erykah Badu
# 1. Didn't Cha Know
# 2. On & On
# 3. Next Lifetime
# 4. Appletree
# 5. Window Seat
# 6. Other Side Of The Game
# 7. Orange Moon
# 8. ...& On
# 9. I'll Call U Back
# 10. Bag Lady
# Song names = ["Didn't Cha Know", 'On & On', 'Next Lifetime', 'Appletree', 'Window Seat', 'Other Side Of The Game', 'Orange Moon', '...& On', "I'll Call U Back", 'Bag Lady']
#
#  Top 10 Solo Tracks for R. Kelly
# 1. Ignition - Remix
# 2. I Believe I Can Fly
# 3. Bump n' Grind
# 4. Work - Freemasons Radio Edit
# 5. Your Body's Callin'
# 6. Step In the Name of Love - Remix
# 7. It Seems Like You're Ready
# 8. World Christmas
# 9. Kelly
# Song names = ['Ignition - Remix', 'I Believe I Can Fly', "Bump n' Grind", 'Work - Freemasons Radio Edit', "Your Body's Callin'", 'Step In the Name of Love - Remix', "It Seems Like You're Ready", 'World Christmas', 'Kelly']
#
#  Top 10 Solo Tracks for Mýa
# 1. Gostava Tanto De Você
# 2. Case Of The Ex (Whatcha Gonna Do)
# 3. Me Dê Motivo
# 4. Ecliptica
# 5. Amor a la Antigua
# 6. Tanz der Moleküle - Single Version
# 7. Love Me Right
# 8. Fairy
# 9. Моя дорогая
# 10. E non finisce mica il cielo
# Song names = ['Gostava Tanto De Você', 'Case Of The Ex (Whatcha Gonna Do)', 'Me Dê Motivo', 'Ecliptica', 'Amor a la Antigua', 'Tanz der Moleküle - Single Version', 'Love Me Right', 'Fairy', 'Моя дорогая', 'E non finisce mica il cielo']
#
#  Top 10 Solo Tracks for Tamia
# 1. So Into You
# 2. Officially Missing You
# 3. Can't Get Enough
# 4. Still
# 5. Stranger in My House
# 6. Who Do You Tell?
# 7. Almost
# 8. This Time It's Love
# 9. Careless Whisper
# 10. Never Gonna Let You Go
# Song names = ['So Into You', 'Officially Missing You', "Can't Get Enough", 'Still', 'Stranger in My House', 'Who Do You Tell?', 'Almost', "This Time It's Love", 'Careless Whisper', 'Never Gonna Let You Go']
#
#  Top 10 Solo Tracks for Aloe Blacc
# 1. I Need A Dollar
# 2. The Man
# 3. Wake Me Up - Acoustic
# 4. Brooklyn In The Summer
# 5. Ticking Bomb
# 6. Hold On Tight
# 7. My Way
# 8. Love Is The Answer
# 9. King Is Born
# 10. I Do
# Song names = ['I Need A Dollar', 'The Man', 'Wake Me Up - Acoustic', 'Brooklyn In The Summer', 'Ticking Bomb', 'Hold On Tight', 'My Way', 'Love Is The Answer', 'King Is Born', 'I Do']
#
#  Top 10 Solo Tracks for Keri Hilson
# 1. Energy
# 2. Bae
# 3. Again
# 4. I Like - Jost & Grubert Radio Mix
# 5. Slow Dance
# 6. Say That
# Song names = ['Energy', 'Bae', 'Again', 'I Like - Jost & Grubert Radio Mix', 'Slow Dance', 'Say That']
#
#  Top 10 Solo Tracks for Fantasia
# 1. When I See U
# 2. Song for Denise
# 3. Truth Is
# 4. Song for Denise - Wide Walking Version
# 5. What Christmas Means to Me - from "The Best Man Holiday Original Motion Picture Soundtrack"
# 6. Falling In Love Tonight
# 7. Santa Claus Go Straight To The Ghetto
# 8. Ain't Gon' Beg You
# 9. Hallelujah
# 10. I Believe
# Song names = ['When I See U', 'Song for Denise', 'Truth Is', 'Song for Denise - Wide Walking Version', 'What Christmas Means to Me - from "The Best Man Holiday Original Motion Picture Soundtrack"', 'Falling In Love Tonight', 'Santa Claus Go Straight To The Ghetto', "Ain't Gon' Beg You", 'Hallelujah', 'I Believe']
#
#  Top 10 Solo Tracks for DeJ Loaf
# 1. No Fear
# 2. I Got It
# 3. Try Me
# 4. Running Through My Mind
# 5. Easy Love
# 6. We Be On It
# 7. Changes
# 8. Desire
# 9. Running Through My Mind (Sped Up)
# 10. Been On My Grind
# Song names = ['No Fear', 'I Got It', 'Try Me', 'Running Through My Mind', 'Easy Love', 'We Be On It', 'Changes', 'Desire', 'Running Through My Mind (Sped Up)', 'Been On My Grind']
#
#  Top 10 Solo Tracks for 112
# 1. Dance With Me
# 2. Cupid
# 3. Peaches & Cream
# 4. It's Over Now
# 5. Anywhere
# 6. U Already Know
# 7. Come See Me
# 8. Crazy Over You
# 9. Sweet Love
# 10. Love You Like I Did
# Song names = ['Dance With Me', 'Cupid', 'Peaches & Cream', "It's Over Now", 'Anywhere', 'U Already Know', 'Come See Me', 'Crazy Over You', 'Sweet Love', 'Love You Like I Did']
#
#  Top 10 Solo Tracks for Teyana Taylor
# 1. Gonna Love Me
# 2. Bare Wit Me
# 3. Issues/Hold On
# 4. Rose In Harlem
# 5. Concrete
# 6. Bed of Roses
# 7. Fire Girl
# 8. Long Time
# 9. 3Way
# 10. In Your Skin
# Song names = ['Gonna Love Me', 'Bare Wit Me', 'Issues/Hold On', 'Rose In Harlem', 'Concrete', 'Bed of Roses', 'Fire Girl', 'Long Time', '3Way', 'In Your Skin']
#
#  Top 10 Solo Tracks for Omarion
# 1. Ice Box
# 2. Distance
# 3. For War
# 4. O
# 5. BDY on Me
# 6. Sex Playlist
# 7. Speedin'
# 8. Entourage
# 9. Touch
# 10. Open Up
# Song names = ['Ice Box', 'Distance', 'For War', 'O', 'BDY on Me', 'Sex Playlist', "Speedin'", 'Entourage', 'Touch', 'Open Up']
#
#  Top 10 Solo Tracks for Avenoir
# 1. Shameless
# 2. Art of War
# 3. LINK UP
# 4. Favour
# 5. TMW
# 6. Eve
# 7. AFTER HOURS
# 8. Lady
# 9. D4U - Spotify Singles
# 10. DIFFERENT
# Song names = ['Shameless', 'Art of War', 'LINK UP', 'Favour', 'TMW', 'Eve', 'AFTER HOURS', 'Lady', 'D4U - Spotify Singles', 'DIFFERENT']
#
#  Top 10 Solo Tracks for SWV
# 1. Use Your Heart - Interlude
# 2. Weak
# 3. Rain
# 4. Right Here - Human Nature Radio Mix
# 5. Use Your Heart
# 6. I'm So Into You
# 7. You're the One
# 8. Anything
# 9. You're Always On My Mind
# 10. Give Love On Christmas Day
# Song names = ['Use Your Heart - Interlude', 'Weak', 'Rain', 'Right Here - Human Nature Radio Mix', 'Use Your Heart', "I'm So Into You", "You're the One", 'Anything', "You're Always On My Mind", 'Give Love On Christmas Day']
#
#  Top 10 Solo Tracks for Bow Wow
# 1. Too Little Too Late
# 2. Leave (Get Out)
# 3. Baby It's You
# 4. Leave (Get Out) - 2018
# 5. I Want Candy
# 6. Playin' the Game
# 7. Pole In My Basement
# 8. Take Ya Home
# 9. Fools Rush In (Where Angels Fear To Tread)
# 10. Bow Wow (That's My Name) - Radio Edit
# Song names = ['Too Little Too Late', 'Leave (Get Out)', "Baby It's You", 'Leave (Get Out) - 2018', 'I Want Candy', "Playin' the Game", 'Pole In My Basement', 'Take Ya Home', 'Fools Rush In (Where Angels Fear To Tread)', "Bow Wow (That's My Name) - Radio Edit"]
#
#  Top 10 Solo Tracks for Sisqo
# 1. Thong Song
# 2. Incomplete
# 3. Thong Song - Remix / Edited
# 4. Addicted
# 5. How Can I Love U 2Nite
# 6. Your Love Is Incredible
# 7. Thong Song - Radio Edit
# 8. So Sexual
# 9. Incomplete (Re-Recorded)
# 10. Thong Song - Re-Recorded
# Song names = ['Thong Song', 'Incomplete', 'Thong Song - Remix / Edited', 'Addicted', 'How Can I Love U 2Nite', 'Your Love Is Incredible', 'Thong Song - Radio Edit', 'So Sexual', 'Incomplete (Re-Recorded)', 'Thong Song - Re-Recorded']
#  Top 10 Solo Tracks for Joe
# 1. Piano Man
# 2. Vienna
# 3. Uptown Girl
# 4. She's Always a Woman
# 5. My Life
# 6. We Didn't Start the Fire
# 7. Love Is Only a Feeling
# 8. Just the Way You Are
# 9. PUNK TACTICS
# 10. The River of Dreams
# Song names = ['Piano Man', 'Vienna', 'Uptown Girl', "She's Always a Woman", 'My Life', "We Didn't Start the Fire", 'Love Is Only a Feeling', 'Just the Way You Are', 'PUNK TACTICS', 'The River of Dreams']
#
#  Top 10 Solo Tracks for The-Dream
# 1. I Luv Your Girl
# 2. Rockin' That Shit
# 3. Please, Please, Please Let Me Get What I Want
# 4. Life in a Northern Town
# 5. Falsetto
# 6. Things Can Only Get Better - Remastered
# 7. BOCA
# 8. Scream
# 9. Deja Vu
# 10. Sweet Disaster
# Song names = ['I Luv Your Girl', "Rockin' That Shit", 'Please, Please, Please Let Me Get What I Want', 'Life in a Northern Town', 'Falsetto', 'Things Can Only Get Better - Remastered', 'BOCA', 'Scream', 'Deja Vu', 'Sweet Disaster']
#
#  Top 10 Solo Tracks for Bobby V.
# 1. Slow Down - 12" Version
# 2. Ain't No Love In The Heart Of The City - Single Version
# 3. RONALDINHO
# 4. Tell Me
# 5. AMA DOREN
# 6. Le Pediré
# 7. Brazil Funk Freestyle 🇧🇷
# 8. BANDIT
# 9. I Fought the Law - Single Version
# 10. Blue Velvet
# Song names = ['Slow Down - 12" Version', "Ain't No Love In The Heart Of The City - Single Version", 'RONALDINHO', 'Tell Me', 'AMA DOREN', 'Le Pediré', 'Brazil Funk Freestyle 🇧🇷', 'BANDIT', 'I Fought the Law - Single Version', 'Blue Velvet']
#
#  Top 10 Solo Tracks for Sevyn Streeter
# 1. Taboo
# 2. '97
# 3. How Bad Do You Want It (Oh Yeah)
# 4. HMU
# 5. Sex on the Ceiling
# 6. Yernin
# 7. End Up
# 8. Assumptions
# 9. nEXt
# 10. Run To
# Song names = ['Taboo', "'97", 'How Bad Do You Want It (Oh Yeah)', 'HMU', 'Sex on the Ceiling', 'Yernin', 'End Up', 'Assumptions', 'nEXt', 'Run To']
#
#  Top 10 Solo Tracks for Keith Sweat
# 1. Twisted
# 2. Right and a Wrong Way
# 3. How Deep Is Your Love
# 4. I'll Give All My Love to You
# 5. I Want Her
# 6. (There You Go) Tellin' Me No Again
# 7. I'll Give All My Love to You - Single Version; Remastered
# 8. I'm Not Ready
# 9. In the Rain
# 10. Don't Stop Your Love
# Song names = ['Twisted', 'Right and a Wrong Way', 'How Deep Is Your Love', "I'll Give All My Love to You", 'I Want Her', "(There You Go) Tellin' Me No Again", "I'll Give All My Love to You - Single Version; Remastered", "I'm Not Ready", 'In the Rain', "Don't Stop Your Love"]
#
#  Top 10 Solo Tracks for Jazmine Sullivan
# 1. Bust Your Windows
# 2. Pick Up Your Feelings
# 3. Let It Burn
# 4. In Love With Another Man
# 5. Need U Bad
# 6. Lions, Tigers & Bears
# 7. Hurt Me So Good
# 8. Holding You Down (Goin' in Circles)
# 9. 10 Seconds
# 10. BPW
# Song names = ['Bust Your Windows', 'Pick Up Your Feelings', 'Let It Burn', 'In Love With Another Man', 'Need U Bad', 'Lions, Tigers & Bears', 'Hurt Me So Good', "Holding You Down (Goin' in Circles)", '10 Seconds', 'BPW']
#
#  Top 10 Solo Tracks for Brian McKnight
# 1. Back At One
# 2. One Last Cry
# 3. 6, 8, 12
# 4. Still
# 5. The Only One For Me
# 6. Marry Your Daughter
# 7. Anytime
# 8. Crazy Love
# 9. Love Of My Life
# 10. After the Love Has Gone - Live
# Song names = ['Back At One', 'One Last Cry', '6, 8, 12', 'Still', 'The Only One For Me', 'Marry Your Daughter', 'Anytime', 'Crazy Love', 'Love Of My Life', 'After the Love Has Gone - Live']
#
#  Top 10 Solo Tracks for K-Ci & JoJo
# 1. All My Life
# 2. Tell Me It's Real
# 3. Crazy
# 4. Life
# 5. In Love at Christmas
# 6. Last Night's Letter
# 7. This Very Moment
# 8. 叙情詩 - Remastered 2022
# 9. Love Ballad
# 10. How Could You
# Song names = ['All My Life', "Tell Me It's Real", 'Crazy', 'Life', 'In Love at Christmas', "Last Night's Letter", 'This Very Moment', '叙情詩 - Remastered 2022', 'Love Ballad', 'How Could You']
#
#  Top 10 Solo Tracks for Maxwell
# 1. Ascension (Don't Ever Wonder) - Remastered 2021
# 2. Fortunate
# 3. Pretty Wings - uncut
# 4. Sumthin' Sumthin' - Remastered 2021
# 5. This Woman's Work - 2021 Remaster
# 6. Lifetime - 2021 Remaster
# 7. Get to Know Ya - 2021 Remaster
# 8. Bad Habits - uncut
# 9. Fistful of Tears
# 10. Whenever Wherever Whatever - Remastered 2021
# Song names = ["Ascension (Don't Ever Wonder) - Remastered 2021", 'Fortunate', 'Pretty Wings - uncut', "Sumthin' Sumthin' - Remastered 2021", "This Woman's Work - 2021 Remaster", 'Lifetime - 2021 Remaster', 'Get to Know Ya - 2021 Remaster', 'Bad Habits - uncut', 'Fistful of Tears', 'Whenever Wherever Whatever - Remastered 2021']
#
#  Top 10 Solo Tracks for Emeli Sandé
# 1. Read All About It, Pt. III
# 2. Next To Me
# 3. Clown
# 4. Hurts
# 5. My Kind Of Love
# 6. Heaven
# 7. Breathing Underwater
# 8. Imagine
# 9. Brighter Days
# 10. Shine
# Song names = ['Read All About It, Pt. III', 'Next To Me', 'Clown', 'Hurts', 'My Kind Of Love', 'Heaven', 'Breathing Underwater', 'Imagine', 'Brighter Days', 'Shine']
#
#  Top 10 Solo Tracks for Mase
# 1. Navajo
# 2. Tadow
# 3. Unhinged
# 4. NIGHT DANCER
# 5. What You Wanna Try
# 6. Feel so Good
# 7. All I Ever Wanted
# 8. Brindaremos por él
# 9. Prone
# 10. I Win
# Song names = ['Navajo', 'Tadow', 'Unhinged', 'NIGHT DANCER', 'What You Wanna Try', 'Feel so Good', 'All I Ever Wanted', 'Brindaremos por él', 'Prone', 'I Win']
#
#  Top 10 Solo Tracks for August Alsina
# 1. Kissin' On My Tattoos
# 2. Porn Star
# 3. Wait
# 4. Song Cry
# 5. No Love
# 6. You Deserve
# 7. Pretty
# 8. Right There
# 9. Don't Matter
# 10. Testify
# Song names = ["Kissin' On My Tattoos", 'Porn Star', 'Wait', 'Song Cry', 'No Love', 'You Deserve', 'Pretty', 'Right There', "Don't Matter", 'Testify']
#
#  Top 10 Solo Tracks for SAYGRACE
# 1. Boys Ain't Shit
# 2. You Don't Own Me - Radio Mix
# 3. Church On Sunday
# 4. Used To
# 5. Hell Of A Girl
# 6. Dirty Harry
# 7. How To Love Me
# 8. Coffee
# 9. Violent Crimes (Live at VEVO)
# 10. Love Me Or Leave Me
# Song names = ["Boys Ain't Shit", "You Don't Own Me - Radio Mix", 'Church On Sunday', 'Used To', 'Hell Of A Girl', 'Dirty Harry', 'How To Love Me', 'Coffee', 'Violent Crimes (Live at VEVO)', 'Love Me Or Leave Me']
#
#  Top 10 Solo Tracks for Jagged Edge
# 1. I Gotta Be
# 2. Promise
# 3. Let's Get Married
# 4. Walked Outta Heaven
# 5. He Can't Love U
# 6. Goodbye
# 7. Good Luck Charm
# 8. What You Tryin' To Do
# 9. What's It Like
# 10. Healing
# Song names = ['I Gotta Be', 'Promise', "Let's Get Married", 'Walked Outta Heaven', "He Can't Love U", 'Goodbye', 'Good Luck Charm', "What You Tryin' To Do", "What's It Like", 'Healing']
#
#  Top 10 Solo Tracks for All-4-One
# 1. I Swear
# 2. I Can Love You Like That
# 3. So Much in Love
# 4. These Arms
# 5. Beautiful As U
# 6. If Your Heart’s Not In It
# 7. Rudolph the Rednose Reindeer / Frosty the Snowman
# 8. When I Needed An Angel
# 9. (She's Got) Skillz
# 10. I Can Love You Like That / I Swear Medley
# Song names = ['I Swear', 'I Can Love You Like That', 'So Much in Love', 'These Arms', 'Beautiful As U', 'If Your Heart’s Not In It', 'Rudolph the Rednose Reindeer / Frosty the Snowman', 'When I Needed An Angel', "(She's Got) Skillz", 'I Can Love You Like That / I Swear Medley']
#
#  Top 10 Solo Tracks for Faith Evans
# 1. Love Like This
# 2. Soon as I Get Home
# 3. I Love You
# 4. You Used to Love Me
# 5. Never Gonna Let You Go
# 6. Happy Holiday
# 7. Soulful Christmas
# 8. You Are My Joy (Interlude)
# 9. Kissing You
# 10. O Come All Ye Faithful
# Song names = ['Love Like This', 'Soon as I Get Home', 'I Love You', 'You Used to Love Me', 'Never Gonna Let You Go', 'Happy Holiday', 'Soulful Christmas', 'You Are My Joy (Interlude)', 'Kissing You', 'O Come All Ye Faithful']
#
#  Top 10 Solo Tracks for DaniLeigh
# 1. Put U On
# 2. Easy - Unplugged
# 3. Situations
# 4. Superstar
# 5. Tasty
# 6. Bullshit
# 7. Monique
# 8. Dead To Me
# 9. Last Night
# 10. Keeper
# Song names = ['Put U On', 'Easy - Unplugged', 'Situations', 'Superstar', 'Tasty', 'Bullshit', 'Monique', 'Dead To Me', 'Last Night', 'Keeper']
#
#  Top 10 Solo Tracks for Pretty Ricky
# 1. Grind With Me
# 2. Your Body
# 3. On the Hotline
# 4. Nothing but a Number
# 5. On the Hotline - Amended Version
# 6. Shorty Be Mine
# 7. Juicy (feat. Static Major)
# 8. Love Like Honey
# 9. Get a Little Closer
# 10. Your Body - Amended Version
# Song names = ['Grind With Me', 'Your Body', 'On the Hotline', 'Nothing but a Number', 'On the Hotline - Amended Version', 'Shorty Be Mine', 'Juicy (feat. Static Major)', 'Love Like Honey', 'Get a Little Closer', 'Your Body - Amended Version']
#
#  Top 10 Solo Tracks for Sabrina Claudio
# 1. Frozen
# 2. Stand Still
# 3. Unravel Me
# 4. Orion's Belt
# 5. Confidently Lost
# 6. Problem With You
# 7. All to You
# 8. IOU
# 9. Truth Is
# 10. Belong to You
# Song names = ['Frozen', 'Stand Still', 'Unravel Me', "Orion's Belt", 'Confidently Lost', 'Problem With You', 'All to You', 'IOU', 'Truth Is', 'Belong to You']
#  Top 10 Solo Tracks for Kiana Ledé
# 1. Wicked Games
# 2. EX
# 3. Can't Feel My Face
# 4. Deeper
# 5. Jury
# 6. I Choose You - Acoustic
# 7. Show Love
# 8. LMK
# 9. Focus
# 10. Take It All
# Song names = ['Wicked Games', 'EX', "Can't Feel My Face", 'Deeper', 'Jury', 'I Choose You - Acoustic', 'Show Love', 'LMK', 'Focus', 'Take It All']
#
#  Top 10 Solo Tracks for Musiq Soulchild
# 1. Just Friends (Sunny)
# 2. Halfcrazy
# 3. Love
# 4. sobeautiful
# 5. teachme
# 6. Dontchange
# 7. Buddy
# 8. Deck the Halls
# 9. ifuleave (feat. Mary J. Blige)
# 10. Whoknows
# Song names = ['Just Friends (Sunny)', 'Halfcrazy', 'Love', 'sobeautiful', 'teachme', 'Dontchange', 'Buddy', 'Deck the Halls', 'ifuleave (feat. Mary J. Blige)', 'Whoknows']
#
#  Top 10 Solo Tracks for Queen Naija
# 1. Medicine
# 2. Butterflies
# 3. Karma
# 4. Butterflies Pt. 2
# 5. Mama's Hand
# 6. Pack Lite
# 7. rain...
# 8. Bad Boy
# 9. War Cry
# 10. put it on (eat)...
# Song names = ['Medicine', 'Butterflies', 'Karma', 'Butterflies Pt. 2', "Mama's Hand", 'Pack Lite', 'rain...', 'Bad Boy', 'War Cry', 'put it on (eat)...']
#
#  Top 10 Solo Tracks for Amerie
# 1. 1 Thing
# 2. Why Don't We Fall in Love
# 3. I Just Died
# 4. Talkin' To Me (Edit)
# 5. Rolling Down My Face
# 6. Can't Let Go
# 7. 1 Thing - A Cappella
# 8. Nothing Like Loving You
# 9. All I Have
# 10. Show Me
# Song names = ['1 Thing', "Why Don't We Fall in Love", 'I Just Died', "Talkin' To Me (Edit)", 'Rolling Down My Face', "Can't Let Go", '1 Thing - A Cappella', 'Nothing Like Loving You', 'All I Have', 'Show Me']
#
#  Top 10 Solo Tracks for SoMo
# 1. Ride
# 2. 50 Feet
# 3. Campanas por Doquier
# 4. You Can Buy Everything
# 5. Make Up Sex
# 6. Mejor No Hablar de Ciertas Cosas
# 7. Los Viejos Vinagres
# 8. Largo From Winter
# 9. Heroína
# 10. Regtest
# Song names = ['Ride', '50 Feet', 'Campanas por Doquier', 'You Can Buy Everything', 'Make Up Sex', 'Mejor No Hablar de Ciertas Cosas', 'Los Viejos Vinagres', 'Largo From Winter', 'Heroína', 'Regtest']
#
#  Top 10 Solo Tracks for Babyface
# 1. Fake Luv
# 2. Family > Money
# 3. Palm Angels, Palms Itching
# 4. Winter Wonderland
# 5. Waves On Every Chain
# 6. StreetLightz
# 7. Paper Route Freestyle
# 8. My Thoughts
# 9. White Christmas
# 10. #1 Fan
# Song names = ['Fake Luv', 'Family > Money', 'Palm Angels, Palms Itching', 'Winter Wonderland', 'Waves On Every Chain', 'StreetLightz', 'Paper Route Freestyle', 'My Thoughts', 'White Christmas', '#1 Fan']
#
#  Top 10 Solo Tracks for Remy Ma
# 1. Conceited (There's Something About Remy)
# 2. La Novena Maravilla - En Vivo
# 3. Cada Día Más - En Vivo
# 4. Cinderella
# 5. Disco Man
# 6. Soup
# 7. No Me Queda Más - En Vivo
# 8. Sexy Villain
# 9. Toro
# 10. En Kanimalare -Male (from "Philips & The Monkey Pen")
# Song names = ["Conceited (There's Something About Remy)", 'La Novena Maravilla - En Vivo', 'Cada Día Más - En Vivo', 'Cinderella', 'Disco Man', 'Soup', 'No Me Queda Más - En Vivo', 'Sexy Villain', 'Toro', 'En Kanimalare -Male (from "Philips & The Monkey Pen")']
#
#  Top 10 Solo Tracks for 702
# 1. Get It Together
# 2. Where My Girls At
# 3. Steelo
# 4. You'll Just Never Know
# 5. You Don't Know
# 6. I Still Love You
# 7. Certified
# 8. Prefiero Mentir
# 9. Finding My Way
# 10. Don't Go Breaking My Heart
# Song names = ['Get It Together', 'Where My Girls At', 'Steelo', "You'll Just Never Know", "You Don't Know", 'I Still Love You', 'Certified', 'Prefiero Mentir', 'Finding My Way', "Don't Go Breaking My Heart"]
#
#  Top 10 Solo Tracks for Next
# 1. M a k e I t T o T h e M o r n i n g
# 2. Break from Toronto
# 3. Dreamin
# 4. Belong to the City
# 5. СВЕТЛАНА!
# 6. Her Way
# 7. TBH
# 8. N o C h i l l
# 9. Wus Good / Curious
# 10. Hollywood Action
# Song names = ['M a k e I t T o T h e M o r n i n g', 'Break from Toronto', 'Dreamin', 'Belong to the City', 'СВЕТЛАНА!', 'Her Way', 'TBH', 'N o C h i l l', 'Wus Good / Curious', 'Hollywood Action']
#
#  Top 10 Solo Tracks for Jodeci
# 1. Freek'n You
# 2. Come and Talk to Me - Remix
# 3. Come & Talk To Me
# 4. Forever My Lady
# 5. Cry For You
# 6. Love U 4 Life
# 7. Feenin'
# 8. My Heart Belongs To U
# 9. Stay
# 10. Get On Up
# Song names = ["Freek'n You", 'Come and Talk to Me - Remix', 'Come & Talk To Me', 'Forever My Lady', 'Cry For You', 'Love U 4 Life', "Feenin'", 'My Heart Belongs To U', 'Stay', 'Get On Up']
#
#  Top 10 Solo Tracks for Jennifer Hudson
# 1. Let There Be Joy - Bonus Track
# 2. Spotlight
# 3. And I Am Telling You I'm Not Going
# 4. Golden Slumbers / Carry That Weight
# 5. Santa For Someone
# 6. Mary Did You Know
# 7. If This Isn't Love
# 8. Love You I Do
# 9. Memory - From The Motion Picture Soundtrack "Cats"
# 10. Christmas (Baby Please Come Home)
# Song names = ['Let There Be Joy - Bonus Track', 'Spotlight', "And I Am Telling You I'm Not Going", 'Golden Slumbers / Carry That Weight', 'Santa For Someone', 'Mary Did You Know', "If This Isn't Love", 'Love You I Do', 'Memory - From The Motion Picture Soundtrack "Cats"', 'Christmas (Baby Please Come Home)']
#
#  Top 10 Solo Tracks for Anthony Hamilton
# 1. Charlene
# 2. Best of Me
# 3. Her Heart
# 4. The Point Of It All
# 5. Comin' from Where I'm From - Radio Mix
# 6. Pray For Me
# 7. Can't Let Go
# 8. Spend Christmas With You
# 9. I'm A Mess
# 10. 'Tis The Season
# Song names = ['Charlene', 'Best of Me', 'Her Heart', 'The Point Of It All', "Comin' from Where I'm From - Radio Mix", 'Pray For Me', "Can't Let Go", 'Spend Christmas With You', "I'm A Mess", "'Tis The Season"]
#
#  Top 10 Solo Tracks for Tyrese
# 1. How You Gonna Act Like That
# 2. Sweet Lady
# 3. What Am I Gonna Do
# 4. Lately
# 5. Signs of Love Makin'
# 6. Just A Baby Boy - Radio Edit
# 7. On Top Of Me
# 8. Nobody Else
# 9. I Like Them Girls
# 10. Rescue
# Song names = ['How You Gonna Act Like That', 'Sweet Lady', 'What Am I Gonna Do', 'Lately', "Signs of Love Makin'", 'Just A Baby Boy - Radio Edit', 'On Top Of Me', 'Nobody Else', 'I Like Them Girls', 'Rescue']
#
#  Top 10 Solo Tracks for Dru Hill
# 1. How Deep Is Your Love
# 2. Beauty
# 3. Tell Me
# 4. These Are The Times
# 5. In My Bed
# 6. true
# 7. The Love We Had (Stays On My Mind)
# 8. Never Make A Promise
# 9. my shelter - Instrumental
# 10. Perfect Timing
# Song names = ['How Deep Is Your Love', 'Beauty', 'Tell Me', 'These Are The Times', 'In My Bed', 'true', 'The Love We Had (Stays On My Mind)', 'Never Make A Promise', 'my shelter - Instrumental', 'Perfect Timing']
#
#  Top 10 Solo Tracks for Donell Jones
# 1. Where I Wanna Be
# 2. This Luv
# 3. Shorty (Got Her Eyes on Me)
# 4. Knocks Me Off My Feet
# 5. Natural Thang
# 6. Have You Seen Her
# 7. You Know That I Love You
# 8. I Hope It's You
# 9. Groove On
# 10. U Know What's Up
# Song names = ['Where I Wanna Be', 'This Luv', 'Shorty (Got Her Eyes on Me)', 'Knocks Me Off My Feet', 'Natural Thang', 'Have You Seen Her', 'You Know That I Love You', "I Hope It's You", 'Groove On', "U Know What's Up"]
#
#  Top 10 Solo Tracks for B2K
# 1. Ya Me Enteré
# 2. Soulmate
# 3. Hark! The Herald Angels Sing/It Came Upon A Midnight Clear - Medley / Remastered 2006
# 4. Diva
# 5. Girlfriend
# 6. Uh Huh
# 7. Jingle Bells
# 8. Gots Ta Be
# 9. Why'd You Leave Me On Christmas
# 10. Take It To The Floor
# Song names = ['Ya Me Enteré', 'Soulmate', 'Hark! The Herald Angels Sing/It Came Upon A Midnight Clear - Medley / Remastered 2006', 'Diva', 'Girlfriend', 'Uh Huh', 'Jingle Bells', 'Gots Ta Be', "Why'd You Leave Me On Christmas", 'Take It To The Floor']
#
#  Top 10 Solo Tracks for Mila J
# 1. The Christmas Waltz
# 2. Kickin’ Back
# 3. Anderer Mann
# 4. Red Sun - Maniac Agenda Mix
# 5. Just Like Heaven
# 6. leer
# 7. It Kills Me
# 8. Pebble Garden
# 9. Before We Go
# 10. Voel Je Dan Niet?
# Song names = ['The Christmas Waltz', 'Kickin’ Back', 'Anderer Mann', 'Red Sun - Maniac Agenda Mix', 'Just Like Heaven', 'leer', 'It Kills Me', 'Pebble Garden', 'Before We Go', 'Voel Je Dan Niet?']
